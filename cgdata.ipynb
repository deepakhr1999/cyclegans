# %%
from src.UnpairedDataset import UnpairedDataset

# %%
root = 'C:/Users/Deepak H R/Desktop/data/monet2photo/'
train = UnpairedDataset(root, 'train')
# Out:
# Found 1072 images of trainA and 6287 images of trainB

# %%
print(train[0]['pathA'])
train[0]["A"]
# Out:
# C:/Users/Deepak H R/Desktop/data/monet2photo/trainA\00001.jpg
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=256x256 at 0x1C4BBA18F88>

# %%
print(train[0]['pathB'])
train[0]["B"]
# Out:
# C:/Users/Deepak H R/Desktop/data/monet2photo/trainB\2013-11-08 16_45_24.jpg
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=256x256 at 0x1C4BBB318C8>
